# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import re
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
import re
import matplotlib.pyplot as plt

# %%
ps=PorterStemmer()

# %% [markdown]
# # Function for cleaning an given text
# It removes characters other than a-z, Converts the string to lower case, Removes stop words and splits each word

# %%
def clean(text):
    text = re.sub('[^a-zA-Z]', " ", text)
    text = text.lower()
    text = text.split()
    text = [ps.stem(word) for word in text if word not in stopwords.words("english")]
    text = ' '.join(text)
    return text

# %% [markdown]
# # Read dataframe using pandas and giving the second row as column labels

# %%
df=pd.read_csv(r"C:\Users\91880\Downloads\browser_rankings_data.csv",header=1)

# %%
df
# Out:
#           ID          Keyword  Rank Country Language        Date  \
# 0          1          browser   2.0      in       en  2020-12-16
# 1          2          browser   3.0      in       en  2020-12-16
# 2          3          browser   4.0      in       en  2020-12-16
# 3          3          browser   4.0      in       en  2020-12-16
# 4          4          browser   1.0      in       en  2020-12-16
# ...      ...              ...   ...     ...      ...         ...
# 3061  131575  android browser   7.0      in       en  2021-03-06
# 3062  131576  android browser   5.0      in       en  2021-03-06
# 3063  131576  android browser   5.0      in       en  2021-03-06
# 3064  131576  android browser   5.0      in       en  2021-03-06
# 3065  131576  android browser   5.0      in       en  2021-03-06
#
#                       App ID Date of Last Description Change  \
# 0       net.fast.web.browser                      2020-12-18
# 1         com.android.chrome                      2020-12-18
# 2          com.opera.browser                      2021-02-27
# 3          com.opera.browser                      2020-12-18
# 4     com.cloudmosa.puffinTV                      2021-02-07
# ...                      ...                             ...
# 3061       com.opera.browser                      2020-12-18
# 3062  com.cloudmosa.puffinTV                      2021-02-07
# 3063  com.cloudmosa.puffinTV                      2021-02-06
# 3064  com.cloudmosa.puffinTV                      2021-01-21
# 3065  com.cloudmosa.puffinTV                      2020-12-18
#
#                                       Short Description  \
# 0     The small, fastest, secure Web Browser, best m...
# 1     Fast, simple, and secure. Google Chrome browse...
# 2     Fast, safe web browser: free VPN, Ad blocker, ...
# 3     Fast, safe web browser: free VPN, Ad blocker, ...
# 4     Puffin TV Browser - One App to Watch All Video...
# ...                                                 ...
# 3061  Fast, safe web browser: free VPN, Ad blocker, ...
# 3062  Puffin TV Browser - One App to Watch All Video...
# 3063  Puffin TV Browser - One App to Watch All Video...
# 3064  Puffin TV Browser - One App to Watch All Video...
# 3065  Puffin TV Browser - One App to Watch All Video...
#
#                                        Long Description
# 0     One of the smallest, fastest, secure Web Brows...
# 1     Google Chrome is a fast, easy to use, and secu...
# 2     Fast, safe and private, introducing the latest...
# 3     Opera is a fast, safe web browser for your And...
# 4     Puffin TV Browser is a special edition of Puff...
# ...                                                 ...
# 3061  Opera is a fast, safe web browser for your And...
# 3062  Puffin TV Browser is a special edition of Puff...
# 3063  Puffin TV Browser is a special edition of Puff...
# 3064  Puffin TV Browser is a special edition of Puff...
# 3065  Puffin TV Browser is a special edition of Puff...
#
# [3066 rows x 10 columns]

# %% [markdown]
# # Applying the clean function for short description and long description, For app id we remove all the special characters

# %%
df['Short Description']=df['Short Description'].apply(lambda x: clean(str(x)))
df['Long Description']=df['Long Description'].apply(lambda x: clean(str(x)))
df['App ID']=df['App ID'].apply(lambda x: re.sub('[^a-zA-Z]', " ", str(x)))

# %% [markdown]
# # Checking for null values

# %%
df.isna().sum()
# Out:
# ID                                  0
# Keyword                             0
# Rank                               16
# Country                             0
# Language                            0
# Date                                0
# App ID                              0
# Date of Last Description Change     0
# Short Description                   0
# Long Description                    0
# dtype: int64

# %% [markdown]
# # Less number of null values, so it can be dropped

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# ID                                 0
# Keyword                            0
# Rank                               0
# Country                            0
# Language                           0
# Date                               0
# App ID                             0
# Date of Last Description Change    0
# Short Description                  0
# Long Description                   0
# dtype: int64

# %% [markdown]
# # Country and Language is same for all so lets drop it

# %%
df.drop(['Country','Language'],axis=1,inplace=True)
df
# Out:
#           ID          Keyword  Rank        Date                  App ID  \
# 0          1          browser   2.0  2020-12-16    net fast web browser
# 1          2          browser   3.0  2020-12-16      com android chrome
# 2          3          browser   4.0  2020-12-16       com opera browser
# 3          3          browser   4.0  2020-12-16       com opera browser
# 4          4          browser   1.0  2020-12-16  com cloudmosa puffinTV
# ...      ...              ...   ...         ...                     ...
# 3061  131575  android browser   7.0  2021-03-06       com opera browser
# 3062  131576  android browser   5.0  2021-03-06  com cloudmosa puffinTV
# 3063  131576  android browser   5.0  2021-03-06  com cloudmosa puffinTV
# 3064  131576  android browser   5.0  2021-03-06  com cloudmosa puffinTV
# 3065  131576  android browser   5.0  2021-03-06  com cloudmosa puffinTV
#
#      Date of Last Description Change  \
# 0                         2020-12-18
# 1                         2020-12-18
# 2                         2021-02-27
# 3                         2020-12-18
# 4                         2021-02-07
# ...                              ...
# 3061                      2020-12-18
# 3062                      2021-02-07
# 3063                      2021-02-06
# 3064                      2021-01-21
# 3065                      2020-12-18
#
#                                       Short Description  \
# 0     small fastest secur web browser best mobil bro...
# 1     fast simpl secur googl chrome browser android ...
# 2     fast safe web browser free vpn ad blocker qr c...
# 3     fast safe web browser free vpn ad blocker qr c...
# 4             puffin tv browser one app watch video web
# ...                                                 ...
# 3061  fast safe web browser free vpn ad blocker qr c...
# 3062          puffin tv browser one app watch video web
# 3063          puffin tv browser one app watch video web
# 3064          puffin tv browser one app watch video web
# 3065          puffin tv browser one app watch video web
#
#                                        Long Description
# 0     one smallest fastest secur web browser specif ...
# 1     googl chrome fast easi use secur web browser d...
# 2     fast safe privat introduc latest version opera...
# 3     opera fast safe web browser android devic feat...
# 4     puffin tv browser special edit puffin web brow...
# ...                                                 ...
# 3061  opera fast safe web browser android devic feat...
# 3062  puffin tv browser special edit puffin web brow...
# 3063  puffin tv browser special edit puffin web brow...
# 3064  puffin tv browser special edit puffin web brow...
# 3065  puffin tv browser special edit puffin web brow...
#
# [3050 rows x 8 columns]

# %% [markdown]
# # Lets groupy according to app_id and rank - to find any insights

# %%
gk = df.groupby(['App ID','Rank'])
gk.first()
# Out:
#                                ID          Keyword        Date  \
# App ID               Rank
# com android chrome   1.0    13588          browser  2020-12-29
#                      2.0    12286          browser  2020-12-28
#                      3.0        2          browser  2020-12-16
#                      4.0       44          browser  2020-12-17
#                      5.0    26140          browser  2021-01-08
# ...                           ...              ...         ...
# net fast web browser 13.0     228  android browser  2020-12-19
#                      14.0      45  android browser  2020-12-17
#                      15.0   16594          browser  2020-12-31
#                      16.0   19246  android browser  2021-01-02
#                      24.0  124901  android browser  2021-03-03
#
#                           Date of Last Description Change  \
# App ID               Rank
# com android chrome   1.0                       2020-12-18
#                      2.0                       2020-12-18
#                      3.0                       2020-12-18
#                      4.0                       2020-12-18
#                      5.0                       2020-12-18
# ...                                                   ...
# net fast web browser 13.0                      2020-12-18
#                      14.0                      2020-12-18
#                      15.0                      2020-12-18
#                      16.0                      2020-12-18
#                      24.0                      2020-12-18
#
#                                                            Short Description  \
# App ID               Rank
# com android chrome   1.0   fast simpl secur googl chrome browser android ...
#                      2.0   fast simpl secur googl chrome browser android ...
#                      3.0   fast simpl secur googl chrome browser android ...
#                      4.0   fast simpl secur googl chrome browser android ...
#                      5.0   fast simpl secur googl chrome browser android ...
# ...                                                                      ...
# net fast web browser 13.0  small fastest secur web browser best mobil bro...
#                      14.0  small fastest secur web browser best mobil bro...
#                      15.0  small fastest secur web browser best mobil bro...
#                      16.0  small fastest secur web browser best mobil bro...
#                      24.0  small fastest secur web browser best mobil bro...
#
#                                                             Long Description
# App ID               Rank
# com android chrome   1.0   googl chrome fast easi use secur web browser d...
#                      2.0   googl chrome fast easi use secur web browser d...
#                      3.0   googl chrome fast easi use secur web browser d...
#                      4.0   googl chrome fast easi use secur web browser d...
#                      5.0   googl chrome fast easi use secur web browser d...
# ...                                                                      ...
# net fast web browser 13.0  one smallest fastest secur web browser specif ...
#                      14.0  one smallest fastest secur web browser specif ...
#                      15.0  one smallest fastest secur web browser specif ...
#                      16.0  one smallest fastest secur web browser specif ...
#                      24.0  one smallest fastest secur web browser specif ...
#
# [275 rows x 6 columns]

# %% [markdown]
# # As we can see for the same app_id the rank is changing, To further analyze lets groupby the date and rank

# %%
gk = df.groupby(['Date', 'Rank'])
gk.first()
# Out:
#                       ID                       Keyword  \
# Date       Rank
# 2020-12-16 1.0         4                       browser
#            2.0         1                       browser
#            3.0         2                       browser
#            4.0         3                       browser
#            8.0         6               android browser
# ...                  ...                           ...
# 2021-03-06 31.0   129885               ad free browser
#            38.0   129870  privacy browsers for android
#            44.0   129874         best privacy browsers
#            83.0   129878                  fast browser
#            106.0  129866               privacy browser
#
#                                   App ID Date of Last Description Change  \
# Date       Rank
# 2020-12-16 1.0    com cloudmosa puffinTV                      2021-02-07
#            2.0      net fast web browser                      2020-12-18
#            3.0        com android chrome                      2020-12-18
#            4.0         com opera browser                      2021-02-27
#            8.0        com android chrome                      2020-12-18
# ...                                  ...                             ...
# 2021-03-06 31.0    com transsion phoenix                      2020-12-18
#            38.0      com vivaldi browser                      2020-12-18
#            44.0      com vivaldi browser                      2020-12-18
#            83.0      com vivaldi browser                      2020-12-18
#            106.0     com vivaldi browser                      2020-12-18
#
#                                                   Short Description  \
# Date       Rank
# 2020-12-16 1.0            puffin tv browser one app watch video web
#            2.0    small fastest secur web browser best mobil bro...
#            3.0    fast simpl secur googl chrome browser android ...
#            4.0    fast safe web browser free vpn ad blocker qr c...
#            8.0    fast simpl secur googl chrome browser android ...
# ...                                                             ...
# 2021-03-06 31.0   funni video footbal amp celebr news fast amp d...
#            38.0   fast amp privat web browser ad blocker sync da...
#            44.0   fast amp privat web browser ad blocker sync da...
#            83.0   fast amp privat web browser ad blocker sync da...
#            106.0  fast amp privat web browser ad blocker sync da...
#
#                                                    Long Description
# Date       Rank
# 2020-12-16 1.0    puffin tv browser special edit puffin web brow...
#            2.0    one smallest fastest secur web browser specif ...
#            3.0    googl chrome fast easi use secur web browser d...
#            4.0    fast safe privat introduc latest version opera...
#            8.0    googl chrome fast easi use secur web browser d...
# ...                                                             ...
# 2021-03-06 31.0   phoenix browser fast safe web browser android ...
#            38.0   vivaldi new privat web browser integr ad block...
#            44.0   vivaldi new privat web browser integr ad block...
#            83.0   vivaldi new privat web browser integr ad block...
#            106.0  vivaldi new privat web browser integr ad block...
#
# [1352 rows x 6 columns]

# %% [markdown]
# # So from observing we can say that for a particular date the rank is varying according to the 'keyword' for the same app

# %% [markdown]
# # Code to find the place in which keyword occurs in short and long description

# %%
# Entering a column factor that tells how near the keyword is present in both short and long description
df['s_factor']=0
df['l_factor']=0

# Loop to iterate index values
for n in df.index:
    
    #Temporary variables that hold each words in the short description and keywords
    temp1 = re.findall(r'\w+', str(df['Short Description'][n])) 
    temp2 = re.findall(r'\w+', str(df['Keyword'][n])) 
    
    #Loop to find keyword in short description
    for i in temp2:
        
        #variable that returns the place
        count1=0
        
        for j in temp1:
            count1+=1
            if i==j:
                df['s_factor'][n]+=count1
                break
                
    #Temporary variables that hold each words in the long description and keywords
    temp1 = re.findall(r'\w+', str(df['Long Description'][n]))
    temp2 = re.findall(r'\w+', str(df['Keyword'][n]))
    
    #Loop to find keyword in long description
    for i in temp2:
        
        #variable that returns the place
        count2=0
        
        for j in temp1:
            count2+=1
            if i==j:
                df['l_factor'][n]+=count2
                break
# Out:
# C:\Users\91880\AppData\Local\Temp\ipykernel_184\525230147.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['s_factor'][n]+=count1
# C:\Users\91880\AppData\Local\Temp\ipykernel_184\525230147.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['l_factor'][n]+=count2

# %% [markdown]
# # Here if the factor is less then it means the keyword is found at the very start of short and long description, If factor is zero then it means the keyword is not present in both short and long description

# %%
df['factor']=df['s_factor']+df['l_factor']
df
# Out:
#           ID          Keyword  Rank        Date                  App ID  \
# 0          1          browser   2.0  2020-12-16    net fast web browser
# 1          2          browser   3.0  2020-12-16      com android chrome
# 2          3          browser   4.0  2020-12-16       com opera browser
# 3          3          browser   4.0  2020-12-16       com opera browser
# 4          4          browser   1.0  2020-12-16  com cloudmosa puffinTV
# ...      ...              ...   ...         ...                     ...
# 3061  131575  android browser   7.0  2021-03-06       com opera browser
# 3062  131576  android browser   5.0  2021-03-06  com cloudmosa puffinTV
# 3063  131576  android browser   5.0  2021-03-06  com cloudmosa puffinTV
# 3064  131576  android browser   5.0  2021-03-06  com cloudmosa puffinTV
# 3065  131576  android browser   5.0  2021-03-06  com cloudmosa puffinTV
#
#      Date of Last Description Change  \
# 0                         2020-12-18
# 1                         2020-12-18
# 2                         2021-02-27
# 3                         2020-12-18
# 4                         2021-02-07
# ...                              ...
# 3061                      2020-12-18
# 3062                      2021-02-07
# 3063                      2021-02-06
# 3064                      2021-01-21
# 3065                      2020-12-18
#
#                                       Short Description  \
# 0     small fastest secur web browser best mobil bro...
# 1     fast simpl secur googl chrome browser android ...
# 2     fast safe web browser free vpn ad blocker qr c...
# 3     fast safe web browser free vpn ad blocker qr c...
# 4             puffin tv browser one app watch video web
# ...                                                 ...
# 3061  fast safe web browser free vpn ad blocker qr c...
# 3062          puffin tv browser one app watch video web
# 3063          puffin tv browser one app watch video web
# 3064          puffin tv browser one app watch video web
# 3065          puffin tv browser one app watch video web
#
#                                        Long Description  factor  s_factor  \
# 0     one smallest fastest secur web browser specif ...      11         5
# 1     googl chrome fast easi use secur web browser d...      14         6
# 2     fast safe privat introduc latest version opera...      13         4
# 3     opera fast safe web browser android devic feat...       9         4
# 4     puffin tv browser special edit puffin web brow...       6         3
# ...                                                 ...     ...       ...
# 3061  opera fast safe web browser android devic feat...      15         4
# 3062  puffin tv browser special edit puffin web brow...      16         3
# 3063  puffin tv browser special edit puffin web brow...      16         3
# 3064  puffin tv browser special edit puffin web brow...      16         3
# 3065  puffin tv browser special edit puffin web brow...      16         3
#
#       l_factor
# 0            6
# 1            8
# 2            9
# 3            5
# 4            3
# ...        ...
# 3061        11
# 3062        13
# 3063        13
# 3064        13
# 3065        13
#
# [3050 rows x 11 columns]

# %% [markdown]
# # Groupby to compare the factor values

# %%
gk = df.groupby(['Date', 'Rank'])
gk.first()
# Out:
#                       ID                       Keyword  \
# Date       Rank
# 2020-12-16 1.0         4                       browser
#            2.0         1                       browser
#            3.0         2                       browser
#            4.0         3                       browser
#            8.0         6               android browser
# ...                  ...                           ...
# 2021-03-06 31.0   129885               ad free browser
#            38.0   129870  privacy browsers for android
#            44.0   129874         best privacy browsers
#            83.0   129878                  fast browser
#            106.0  129866               privacy browser
#
#                                   App ID Date of Last Description Change  \
# Date       Rank
# 2020-12-16 1.0    com cloudmosa puffinTV                      2021-02-07
#            2.0      net fast web browser                      2020-12-18
#            3.0        com android chrome                      2020-12-18
#            4.0         com opera browser                      2021-02-27
#            8.0        com android chrome                      2020-12-18
# ...                                  ...                             ...
# 2021-03-06 31.0    com transsion phoenix                      2020-12-18
#            38.0      com vivaldi browser                      2020-12-18
#            44.0      com vivaldi browser                      2020-12-18
#            83.0      com vivaldi browser                      2020-12-18
#            106.0     com vivaldi browser                      2020-12-18
#
#                                                   Short Description  \
# Date       Rank
# 2020-12-16 1.0            puffin tv browser one app watch video web
#            2.0    small fastest secur web browser best mobil bro...
#            3.0    fast simpl secur googl chrome browser android ...
#            4.0    fast safe web browser free vpn ad blocker qr c...
#            8.0    fast simpl secur googl chrome browser android ...
# ...                                                             ...
# 2021-03-06 31.0   funni video footbal amp celebr news fast amp d...
#            38.0   fast amp privat web browser ad blocker sync da...
#            44.0   fast amp privat web browser ad blocker sync da...
#            83.0   fast amp privat web browser ad blocker sync da...
#            106.0  fast amp privat web browser ad blocker sync da...
#
#                                                    Long Description  factor  \
# Date       Rank
# 2020-12-16 1.0    puffin tv browser special edit puffin web brow...       6
#            2.0    one smallest fastest secur web browser specif ...      11
#            3.0    googl chrome fast easi use secur web browser d...      14
#            4.0    fast safe privat introduc latest version opera...      13
#            8.0    googl chrome fast easi use secur web browser d...      31
# ...                                                             ...     ...
# 2021-03-06 31.0   phoenix browser fast safe web browser android ...     133
#            38.0   vivaldi new privat web browser integr ad block...       0
#            44.0   vivaldi new privat web browser integr ad block...       0
#            83.0   vivaldi new privat web browser integr ad block...      40
#            106.0  vivaldi new privat web browser integr ad block...      10
#
#                   s_factor  l_factor
# Date       Rank
# 2020-12-16 1.0           3         3
#            2.0           5         6
#            3.0           6         8
#            4.0           4         9
#            8.0          13        18
# ...                    ...       ...
# 2021-03-06 31.0         11       122
#            38.0          0         0
#            44.0          0         0
#            83.0          6        34
#            106.0         5         5
#
# [1352 rows x 9 columns]

# %% [markdown]
# # So the placement of keyword in short and long description is important in ranking of the app

# %% [markdown]
# # So the short and long description is corelated with ranking through the keywords

# %%
plt.scatter(df['factor'],df['Rank'])
plt.xlabel('Factor')
plt.ylabel('Rank')
plt.title('Rank vs Factor')
plt.show()

# %% [markdown]
# # Mostly if factor(depends on the placement of keyword) is low we can say that the rank will be low

# %% [markdown]
# # But we can  also see low ranks for high factor values and high ranks for low factor values, To find this we can sort by factor values

# %%
df.sort_values('factor')
# Out:
#           ID                       Keyword   Rank        Date  \
# 779    22906  privacy browsers for android   94.0  2021-01-06
# 491    14522  privacy browsers for android   59.0  2020-12-30
# 496    14526         best privacy browsers   58.0  2020-12-30
# 2586  105708         best privacy browsers  117.0  2021-02-23
# 2581  105704  privacy browsers for android   60.0  2021-02-23
# ...      ...                           ...    ...         ...
# 643    19245               android browser    5.0  2021-01-02
# 1259   39873               android browser    2.0  2021-01-17
# 369    11148               android browser    3.0  2020-12-27
# 2941  124904               android browser    8.0  2021-03-03
# 413    12288               android browser    3.0  2020-12-28
#
#                    App ID Date of Last Description Change  \
# 779   com vivaldi browser                      2020-12-18
# 491   com vivaldi browser                      2020-12-18
# 496   com vivaldi browser                      2020-12-18
# 2586  com vivaldi browser                      2020-12-18
# 2581  com vivaldi browser                      2020-12-18
# ...                   ...                             ...
# 643     com opera browser                      2021-02-27
# 1259    com opera browser                      2021-02-27
# 369     com opera browser                      2021-02-27
# 2941    com opera browser                      2021-02-27
# 413     com opera browser                      2021-02-27
#
#                                       Short Description  \
# 779   fast amp privat web browser ad blocker sync da...
# 491   fast amp privat web browser ad blocker sync da...
# 496   fast amp privat web browser ad blocker sync da...
# 2586  fast amp privat web browser ad blocker sync da...
# 2581  fast amp privat web browser ad blocker sync da...
# ...                                                 ...
# 643   fast safe web browser free vpn ad blocker qr c...
# 1259  fast safe web browser free vpn ad blocker qr c...
# 369   fast safe web browser free vpn ad blocker qr c...
# 2941  fast safe web browser free vpn ad blocker qr c...
# 413   fast safe web browser free vpn ad blocker qr c...
#
#                                        Long Description  factor  s_factor  \
# 779   vivaldi new privat web browser integr ad block...       0         0
# 491   vivaldi new privat web browser integr ad block...       0         0
# 496   vivaldi new privat web browser integr ad block...       0         0
# 2586  vivaldi new privat web browser integr ad block...       0         0
# 2581  vivaldi new privat web browser integr ad block...       0         0
# ...                                                 ...     ...       ...
# 643   fast safe privat introduc latest version opera...     283         4
# 1259  fast safe privat introduc latest version opera...     283         4
# 369   fast safe privat introduc latest version opera...     283         4
# 2941  fast safe privat introduc latest version opera...     283         4
# 413   fast safe privat introduc latest version opera...     283         4
#
#       l_factor
# 779          0
# 491          0
# 496          0
# 2586         0
# 2581         0
# ...        ...
# 643        279
# 1259       279
# 369        279
# 2941       279
# 413        279
#
# [3050 rows x 11 columns]

# %% [markdown]
# # When the keyword is more than one word then the factor calculated will be sum of placement of all words, Hence even if factor is less it may not contain all the words from the keywords and hence the reason for the variation found in the graph

# %% [markdown]
# # Now lets findout whether app_id or any other values affect the ranking, Lets take keywords with one letter for more clarity

# %%
pd.set_option('display.max_rows',500)
df_new=df[df['Keyword']=='browser']
df_new
# Out:
#           ID  Keyword  Rank        Date                  App ID  \
# 0          1  browser   2.0  2020-12-16    net fast web browser
# 1          2  browser   3.0  2020-12-16      com android chrome
# 2          3  browser   4.0  2020-12-16       com opera browser
# 3          3  browser   4.0  2020-12-16       com opera browser
# 4          4  browser   1.0  2020-12-16  com cloudmosa puffinTV
# ...      ...      ...   ...         ...                     ...
# 3053  131571  browser  10.0  2021-03-06       com opera browser
# 3054  131572  browser   4.0  2021-03-06  com cloudmosa puffinTV
# 3055  131572  browser   4.0  2021-03-06  com cloudmosa puffinTV
# 3056  131572  browser   4.0  2021-03-06  com cloudmosa puffinTV
# 3057  131572  browser   4.0  2021-03-06  com cloudmosa puffinTV
#
#      Date of Last Description Change  \
# 0                         2020-12-18
# 1                         2020-12-18
# 2                         2021-02-27
# 3                         2020-12-18
# 4                         2021-02-07
# ...                              ...
# 3053                      2020-12-18
# 3054                      2021-02-07
# 3055                      2021-02-06
# 3056                      2021-01-21
# 3057                      2020-12-18
#
#                                       Short Description  \
# 0     small fastest secur web browser best mobil bro...
# 1     fast simpl secur googl chrome browser android ...
# 2     fast safe web browser free vpn ad blocker qr c...
# 3     fast safe web browser free vpn ad blocker qr c...
# 4             puffin tv browser one app watch video web
# ...                                                 ...
# 3053  fast safe web browser free vpn ad blocker qr c...
# 3054          puffin tv browser one app watch video web
# 3055          puffin tv browser one app watch video web
# 3056          puffin tv browser one app watch video web
# 3057          puffin tv browser one app watch video web
#
#                                        Long Description  factor  s_factor  \
# 0     one smallest fastest secur web browser specif ...      11         5
# 1     googl chrome fast easi use secur web browser d...      14         6
# 2     fast safe privat introduc latest version opera...      13         4
# 3     opera fast safe web browser android devic feat...       9         4
# 4     puffin tv browser special edit puffin web brow...       6         3
# ...                                                 ...     ...       ...
# 3053  opera fast safe web browser android devic feat...       9         4
# 3054  puffin tv browser special edit puffin web brow...       6         3
# 3055  puffin tv browser special edit puffin web brow...       6         3
# 3056  puffin tv browser special edit puffin web brow...       6         3
# 3057  puffin tv browser special edit puffin web brow...       6         3
#
#       l_factor
# 0            6
# 1            8
# 2            9
# 3            5
# 4            3
# ...        ...
# 3053         5
# 3054         3
# 3055         3
# 3056         3
# 3057         3
#
# [608 rows x 11 columns]

# %%
gk = df_new.groupby(['Date', 'Rank'])
gk.first()
# Out:
#                      ID  Keyword                  App ID  \
# Date       Rank
# 2020-12-16 1.0        4  browser  com cloudmosa puffinTV
#            2.0        1  browser    net fast web browser
#            3.0        2  browser      com android chrome
#            4.0        3  browser       com opera browser
# 2020-12-17 1.0       42  browser       com opera browser
#            3.0       43  browser  com cloudmosa puffinTV
#            4.0       44  browser      com android chrome
#            5.0       41  browser    net fast web browser
# 2020-12-18 2.0      102  browser  com cloudmosa puffinTV
#            3.0      104  browser       com opera browser
#            5.0      103  browser    net fast web browser
#            8.0      101  browser      com android chrome
# 2020-12-19 3.0      224  browser    net fast web browser
#            4.0      223  browser       com opera browser
#            8.0      222  browser      com android chrome
#            14.0     221  browser  com cloudmosa puffinTV
# 2020-12-21 1.0      399  browser  com cloudmosa puffinTV
#            2.0      398  browser    net fast web browser
#            4.0      397  browser       com opera browser
#            6.0      400  browser      com android chrome
# 2020-12-22 1.0      630  browser       com opera browser
#            2.0      631  browser  com cloudmosa puffinTV
#            3.0      632  browser      com android chrome
#            4.0      629  browser    net fast web browser
# 2020-12-23 1.0     1513  browser    net fast web browser
#            2.0     1514  browser  com cloudmosa puffinTV
#            3.0     1516  browser       com opera browser
#            4.0     1515  browser      com android chrome
# 2020-12-24 1.0     2487  browser    net fast web browser
#            2.0     2488  browser  com cloudmosa puffinTV
#            4.0     2490  browser       com opera browser
#            15.0    2489  browser      com android chrome
# 2020-12-25 1.0     8961  browser    net fast web browser
#            2.0     8959  browser  com cloudmosa puffinTV
#            5.0     8960  browser       com opera browser
#            11.0    8962  browser      com android chrome
# 2020-12-26 1.0    10032  browser    net fast web browser
#            2.0    10031  browser  com cloudmosa puffinTV
#            4.0    10030  browser       com opera browser
#            10.0   10029  browser      com android chrome
# 2020-12-27 1.0    11146  browser    net fast web browser
#            2.0    11145  browser  com cloudmosa puffinTV
#            3.0    11143  browser      com android chrome
#            5.0    11144  browser       com opera browser
# 2020-12-28 1.0    12285  browser    net fast web browser
#            2.0    12286  browser      com android chrome
#            5.0    12283  browser  com cloudmosa puffinTV
#            7.0    12284  browser       com opera browser
# 2020-12-29 1.0    13588  browser      com android chrome
#            3.0    13589  browser  com cloudmosa puffinTV
#            7.0    13590  browser       com opera browser
#            12.0   13591  browser    net fast web browser
# 2020-12-30 1.0    15298  browser      com android chrome
#            4.0    15297  browser  com cloudmosa puffinTV
#            5.0    15295  browser       com opera browser
#            11.0   15296  browser    net fast web browser
# 2020-12-31 1.0    16591  browser      com android chrome
#            4.0    16592  browser  com cloudmosa puffinTV
#            5.0    16593  browser       com opera browser
#            15.0   16594  browser    net fast web browser
# 2021-01-01 1.0    17818  browser      com android chrome
#            3.0    17819  browser  com cloudmosa puffinTV
#            4.0    17820  browser    net fast web browser
#            10.0   17821  browser       com opera browser
# 2021-01-02 2.0    19240  browser  com cloudmosa puffinTV
#            4.0    19243  browser      com android chrome
#            5.0    19242  browser    net fast web browser
#            7.0    19241  browser       com opera browser
# 2021-01-03 1.0    20432  browser      com android chrome
#            3.0    20430  browser  com cloudmosa puffinTV
#            5.0    20429  browser    net fast web browser
#            6.0    20431  browser       com opera browser
# 2021-01-04 1.0    21150  browser      com android chrome
#            2.0    21149  browser    net fast web browser
#            3.0    21152  browser  com cloudmosa puffinTV
#            7.0    21151  browser       com opera browser
# 2021-01-05 1.0    22480  browser  com cloudmosa puffinTV
#            2.0    22478  browser    net fast web browser
#            3.0    22481  browser      com android chrome
#            5.0    22479  browser       com opera browser
# 2021-01-06 1.0    23913  browser    net fast web browser
#            2.0    23912  browser  com cloudmosa puffinTV
#            4.0    23915  browser       com opera browser
#            8.0    23914  browser      com android chrome
# 2021-01-07 1.0    25188  browser    net fast web browser
#            2.0    25187  browser  com cloudmosa puffinTV
#            6.0    25185  browser       com opera browser
#            13.0   25186  browser      com android chrome
# 2021-01-08 1.0    26139  browser    net fast web browser
#            2.0    26141  browser  com cloudmosa puffinTV
#            5.0    26140  browser      com android chrome
#            8.0    26138  browser       com opera browser
# 2021-01-09 1.0    27564  browser  com cloudmosa puffinTV
#            2.0    27563  browser    net fast web browser
#            7.0    27566  browser      com android chrome
#            9.0    27565  browser       com opera browser
# 2021-01-10 1.0    28648  browser  com cloudmosa puffinTV
#            3.0    28649  browser    net fast web browser
#            5.0    28650  browser       com opera browser
#            14.0   28647  browser      com android chrome
# 2021-01-11 1.0    29838  browser  com cloudmosa puffinTV
#            3.0    29839  browser    net fast web browser
#            7.0    29837  browser       com opera browser
#            13.0   29836  browser      com android chrome
# 2021-01-12 1.0    30868  browser  com cloudmosa puffinTV
#            3.0    30865  browser    net fast web browser
#            8.0    30866  browser       com opera browser
#            13.0   30867  browser      com android chrome
# 2021-01-13 1.0    32466  browser    net fast web browser
#            2.0    32465  browser  com cloudmosa puffinTV
#            3.0    32464  browser       com opera browser
#            10.0   32463  browser      com android chrome
# 2021-01-14 1.0    34189  browser    net fast web browser
#            2.0    34187  browser  com cloudmosa puffinTV
#            3.0    34188  browser       com opera browser
#            10.0   34186  browser      com android chrome
# 2021-01-15 1.0    36155  browser    net fast web browser
#            2.0    36153  browser  com cloudmosa puffinTV
#            3.0    36154  browser       com opera browser
#            14.0   36156  browser      com android chrome
# 2021-01-16 1.0    38049  browser    net fast web browser
#            2.0    38050  browser  com cloudmosa puffinTV
#            3.0    38048  browser       com opera browser
#            14.0   38051  browser      com android chrome
# 2021-01-17 1.0    39868  browser    net fast web browser
#            2.0    39867  browser  com cloudmosa puffinTV
#            3.0    39869  browser       com opera browser
#            11.0   39870  browser      com android chrome
# 2021-01-18 1.0    41583  browser  com cloudmosa puffinTV
#            2.0    41581  browser    net fast web browser
#            3.0    41580  browser       com opera browser
#            12.0   41582  browser      com android chrome
# 2021-01-19 1.0    43478  browser    net fast web browser
#            2.0    43477  browser  com cloudmosa puffinTV
#            5.0    43475  browser       com opera browser
#            15.0   43476  browser      com android chrome
# 2021-01-20 1.0    45500  browser  com cloudmosa puffinTV
#            2.0    45498  browser    net fast web browser
#            6.0    45501  browser       com opera browser
#            17.0   45499  browser      com android chrome
# 2021-01-21 1.0    47339  browser    net fast web browser
#            3.0    47338  browser  com cloudmosa puffinTV
#            4.0    47340  browser       com opera browser
#            8.0    47337  browser      com android chrome
# 2021-01-22 1.0    49233  browser  com cloudmosa puffinTV
#            2.0    49232  browser    net fast web browser
#            4.0    49235  browser       com opera browser
#            17.0   49234  browser      com android chrome
# 2021-01-26 1.0    51135  browser  com cloudmosa puffinTV
#            2.0    51136  browser    net fast web browser
#            3.0    51137  browser       com opera browser
#            6.0    51138  browser      com android chrome
# 2021-01-27 1.0    53193  browser      com android chrome
#            2.0    53192  browser    net fast web browser
#            3.0    53190  browser  com cloudmosa puffinTV
#            4.0    53191  browser       com opera browser
# 2021-01-28 1.0    55238  browser      com android chrome
#            2.0    55237  browser    net fast web browser
#            3.0    55239  browser  com cloudmosa puffinTV
#            4.0    55236  browser       com opera browser
# 2021-01-29 1.0    57058  browser      com android chrome
#            2.0    57056  browser  com cloudmosa puffinTV
#            3.0    57055  browser    net fast web browser
#            5.0    57057  browser       com opera browser
# 2021-01-30 1.0    59067  browser      com android chrome
#            2.0    59066  browser  com cloudmosa puffinTV
#            3.0    59068  browser    net fast web browser
#            5.0    59069  browser       com opera browser
# 2021-01-31 1.0    61086  browser      com android chrome
#            2.0    61087  browser  com cloudmosa puffinTV
#            3.0    61088  browser    net fast web browser
#            5.0    61085  browser       com opera browser
# 2021-02-01 1.0    62905  browser      com android chrome
#            2.0    62906  browser    net fast web browser
#            3.0    62907  browser  com cloudmosa puffinTV
#            7.0    62904  browser       com opera browser
# 2021-02-03 1.0    64886  browser    net fast web browser
#            2.0    64889  browser  com cloudmosa puffinTV
#            3.0    64888  browser      com android chrome
#            4.0    64887  browser       com opera browser
# 2021-02-04 1.0    67006  browser    net fast web browser
#            2.0    67007  browser  com cloudmosa puffinTV
#            3.0    67005  browser      com android chrome
#            4.0    67004  browser       com opera browser
# 2021-02-05 1.0    69061  browser    net fast web browser
#            2.0    69058  browser  com cloudmosa puffinTV
#            6.0    69060  browser       com opera browser
#            20.0   69059  browser      com android chrome
# 2021-02-06 1.0    71378  browser      com android chrome
#            2.0    71379  browser    net fast web browser
#            3.0    71377  browser       com opera browser
#            6.0    71376  browser  com cloudmosa puffinTV
# 2021-02-07 1.0    73391  browser      com android chrome
#            3.0    73394  browser       com opera browser
#            5.0    73392  browser    net fast web browser
#            7.0    73393  browser  com cloudmosa puffinTV
# 2021-02-08 1.0    75480  browser      com android chrome
#            2.0    75477  browser       com opera browser
#            4.0    75478  browser    net fast web browser
#            5.0    75479  browser  com cloudmosa puffinTV
# 2021-02-09 1.0    77570  browser       com opera browser
#            2.0    77568  browser      com android chrome
#            5.0    77567  browser    net fast web browser
#            6.0    77569  browser  com cloudmosa puffinTV
# 2021-02-10 1.0    79768  browser    net fast web browser
#            2.0    79769  browser      com android chrome
#            4.0    79770  browser  com cloudmosa puffinTV
#            5.0    79771  browser       com opera browser
# 2021-02-11 1.0    81577  browser    net fast web browser
#            2.0    81575  browser      com android chrome
#            4.0    81576  browser  com cloudmosa puffinTV
#            5.0    81574  browser       com opera browser
# 2021-02-12 1.0    83661  browser    net fast web browser
#            2.0    83660  browser      com android chrome
#            4.0    83662  browser  com cloudmosa puffinTV
#            5.0    83663  browser       com opera browser
# 2021-02-13 1.0    86226  browser    net fast web browser
#            2.0    86228  browser      com android chrome
#            4.0    86229  browser  com cloudmosa puffinTV
#            5.0    86227  browser       com opera browser
# 2021-02-14 1.0    88270  browser      com android chrome
#            2.0    88269  browser    net fast web browser
#            4.0    88271  browser  com cloudmosa puffinTV
#            8.0    88268  browser       com opera browser
# 2021-02-15 1.0    90192  browser      com android chrome
#            3.0    90191  browser    net fast web browser
#            4.0    90190  browser       com opera browser
#            7.0    90189  browser  com cloudmosa puffinTV
# 2021-02-16 1.0    92346  browser    net fast web browser
#            2.0    92344  browser  com cloudmosa puffinTV
#            4.0    92347  browser      com android chrome
#            7.0    92345  browser       com opera browser
# 2021-02-17 1.0    94266  browser    net fast web browser
#            2.0    94268  browser  com cloudmosa puffinTV
#            8.0    94265  browser      com android chrome
#            10.0   94267  browser       com opera browser
# 2021-02-18 1.0    96250  browser  com cloudmosa puffinTV
#            2.0    96248  browser    net fast web browser
#            8.0    96249  browser      com android chrome
#            14.0   96247  browser       com opera browser
# 2021-02-19 1.0    98225  browser  com cloudmosa puffinTV
#            2.0    98227  browser    net fast web browser
#            8.0    98228  browser      com android chrome
#            14.0   98226  browser       com opera browser
# 2021-02-20 1.0   100560  browser    net fast web browser
#            2.0   100563  browser  com cloudmosa puffinTV
#            9.0   100562  browser       com opera browser
#            16.0  100561  browser      com android chrome
# 2021-02-21 1.0   102360  browser    net fast web browser
#            2.0   102363  browser  com cloudmosa puffinTV
#            9.0   102361  browser       com opera browser
#            16.0  102362  browser      com android chrome
# 2021-02-22 1.0   104534  browser    net fast web browser
#            2.0   104532  browser  com cloudmosa puffinTV
#            10.0  104531  browser       com opera browser
#            14.0  104533  browser      com android chrome
# 2021-02-23 1.0   107062  browser    net fast web browser
#            2.0   107061  browser  com cloudmosa puffinTV
#            10.0  107064  browser       com opera browser
#            14.0  107063  browser      com android chrome
# 2021-02-24 1.0   108726  browser    net fast web browser
#            2.0   108725  browser  com cloudmosa puffinTV
#            3.0   108723  browser       com opera browser
#            16.0  108724  browser      com android chrome
# 2021-02-25 1.0   111555  browser       com opera browser
#            6.0   111554  browser      com android chrome
#            9.0   111556  browser    net fast web browser
#            10.0  111553  browser  com cloudmosa puffinTV
# 2021-02-26 1.0   113777  browser  com cloudmosa puffinTV
#            2.0   113780  browser    net fast web browser
#            3.0   113779  browser       com opera browser
#            4.0   113778  browser      com android chrome
# 2021-02-27 1.0   116001  browser  com cloudmosa puffinTV
#            2.0   116004  browser       com opera browser
#            3.0   116002  browser      com android chrome
#            5.0   116003  browser    net fast web browser
# 2021-02-28 1.0   118226  browser  com cloudmosa puffinTV
#            2.0   118228  browser    net fast web browser
#            3.0   118225  browser       com opera browser
#            5.0                       2021-02-27
#            11.0                      2020-12-18
# 2021-03-03 1.0                       2021-02-07
#            2.0                       2020-12-18
#            3.0                       2021-02-27
#            13.0                      2020-12-18
# 2021-03-04 1.0                       2020-12-18
#            5.0                       2021-02-07
#            6.0                       2020-12-18
#            9.0                       2021-02-27
# 2021-03-05 2.0                       2020-12-18
#            5.0                       2021-02-07
#            6.0                       2020-12-18
#            8.0                       2021-02-27
# 2021-03-06 4.0                       2021-02-07
#            5.0                       2020-12-18
#            7.0                       2020-12-18
#            10.0                      2021-02-27
#
#                                                  Short Description  \
# Date       Rank
# 2020-12-16 1.0           puffin tv browser one app watch video web
#            2.0   small fastest secur web browser best mobil bro...
#            3.0   fast simpl secur googl chrome browser android ...
#            4.0   fast safe web browser free vpn ad blocker qr c...
# 2020-12-17 1.0   fast safe web browser free vpn ad blocker qr c...
#            3.0           puffin tv browser one app watch video web
#            4.0   fast simpl secur googl chrome browser android ...
#            5.0   small fastest secur web browser best mobil bro...
# 2020-12-18 2.0           puffin tv browser one app watch video web
#            3.0   fast safe web browser free vpn ad blocker qr c...
#            5.0   small fastest secur web browser best mobil bro...
#            8.0   fast simpl secur googl chrome browser android ...
# 2020-12-19 3.0   small fastest secur web browser best mobil bro...
#            4.0   fast safe web browser free vpn ad blocker qr c...
#            8.0   fast simpl secur googl chrome browser android ...
#            14.0          puffin tv browser one app watch video web
# 2020-12-21 1.0           puffin tv browser one app watch video web
#            2.0   small fastest secur web browser best mobil bro...
#            4.0   fast safe web browser free vpn ad blocker qr c...
#            6.0   fast simpl secur googl chrome browser android ...
# 2020-12-22 1.0   fast safe web browser free vpn ad blocker qr c...
#            2.0           puffin tv browser one app watch video web
#            3.0   fast simpl secur googl chrome browser android ...
#            4.0   small fastest secur web browser best mobil bro...
# 2020-12-23 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            3.0   fast safe web browser free vpn ad blocker qr c...
#            4.0   fast simpl secur googl chrome browser android ...
# 2020-12-24 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            4.0   fast safe web browser free vpn ad blocker qr c...
#            15.0  fast simpl secur googl chrome browser android ...
# 2020-12-25 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            5.0   fast safe web browser free vpn ad blocker qr c...
#            11.0  fast simpl secur googl chrome browser android ...
# 2020-12-26 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            4.0   fast safe web browser free vpn ad blocker qr c...
#            10.0  fast simpl secur googl chrome browser android ...
# 2020-12-27 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            3.0   fast simpl secur googl chrome browser android ...
#            5.0   fast safe web browser free vpn ad blocker qr c...
# 2020-12-28 1.0   small fastest secur web browser best mobil bro...
#            2.0   fast simpl secur googl chrome browser android ...
#            5.0           puffin tv browser one app watch video web
#            7.0   fast safe web browser free vpn ad blocker qr c...
# 2020-12-29 1.0   fast simpl secur googl chrome browser android ...
#            3.0           puffin tv browser one app watch video web
#            7.0   fast safe web browser free vpn ad blocker qr c...
#            12.0  small fastest secur web browser best mobil bro...
# 2020-12-30 1.0   fast simpl secur googl chrome browser android ...
#            4.0           puffin tv browser one app watch video web
#            5.0   fast safe web browser free vpn ad blocker qr c...
#            11.0  small fastest secur web browser best mobil bro...
# 2020-12-31 1.0   fast simpl secur googl chrome browser android ...
#            4.0           puffin tv browser one app watch video web
#            5.0   fast safe web browser free vpn ad blocker qr c...
#            15.0  small fastest secur web browser best mobil bro...
# 2021-01-01 1.0   fast simpl secur googl chrome browser android ...
#            3.0           puffin tv browser one app watch video web
#            4.0   small fastest secur web browser best mobil bro...
#            10.0  fast safe web browser free vpn ad blocker qr c...
# 2021-01-02 2.0           puffin tv browser one app watch video web
#            4.0   fast simpl secur googl chrome browser android ...
#            5.0   small fastest secur web browser best mobil bro...
#            7.0   fast safe web browser free vpn ad blocker qr c...
# 2021-01-03 1.0   fast simpl secur googl chrome browser android ...
#            3.0           puffin tv browser one app watch video web
#            5.0   small fastest secur web browser best mobil bro...
#            6.0   fast safe web browser free vpn ad blocker qr c...
# 2021-01-04 1.0   fast simpl secur googl chrome browser android ...
#            2.0   small fastest secur web browser best mobil bro...
#            3.0           puffin tv browser one app watch video web
#            7.0   fast safe web browser free vpn ad blocker qr c...
# 2021-01-05 1.0           puffin tv browser one app watch video web
#            2.0   small fastest secur web browser best mobil bro...
#            3.0   fast simpl secur googl chrome browser android ...
#            5.0   fast safe web browser free vpn ad blocker qr c...
# 2021-01-06 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            4.0   fast safe web browser free vpn ad blocker qr c...
#            8.0   fast simpl secur googl chrome browser android ...
# 2021-01-07 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            6.0   fast safe web browser free vpn ad blocker qr c...
#            13.0  fast simpl secur googl chrome browser android ...
# 2021-01-08 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            5.0   fast simpl secur googl chrome browser android ...
#            8.0   fast safe web browser free vpn ad blocker qr c...
# 2021-01-09 1.0           puffin tv browser one app watch video web
#            2.0   small fastest secur web browser best mobil bro...
#            7.0   fast simpl secur googl chrome browser android ...
#            9.0   fast safe web browser free vpn ad blocker qr c...
# 2021-01-10 1.0           puffin tv browser one app watch video web
#            3.0   small fastest secur web browser best mobil bro...
#            5.0   fast safe web browser free vpn ad blocker qr c...
#            14.0  fast simpl secur googl chrome browser android ...
# 2021-01-11 1.0           puffin tv browser one app watch video web
#            3.0   small fastest secur web browser best mobil bro...
#            7.0   fast safe web browser free vpn ad blocker qr c...
#            13.0  fast simpl secur googl chrome browser android ...
# 2021-01-12 1.0           puffin tv browser one app watch video web
#            3.0   small fastest secur web browser best mobil bro...
#            8.0   fast safe web browser free vpn ad blocker qr c...
#            13.0  fast simpl secur googl chrome browser android ...
# 2021-01-13 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            3.0   fast safe web browser free vpn ad blocker qr c...
#            10.0  fast simpl secur googl chrome browser android ...
# 2021-01-14 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            3.0   fast safe web browser free vpn ad blocker qr c...
#            10.0  fast simpl secur googl chrome browser android ...
# 2021-01-15 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            3.0   fast safe web browser free vpn ad blocker qr c...
#            14.0  fast simpl secur googl chrome browser android ...
# 2021-01-16 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            3.0   fast safe web browser free vpn ad blocker qr c...
#            14.0  fast simpl secur googl chrome browser android ...
# 2021-01-17 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            3.0   fast safe web browser free vpn ad blocker qr c...
#            11.0  fast simpl secur googl chrome browser android ...
# 2021-01-18 1.0           puffin tv browser one app watch video web
#            2.0   small fastest secur web browser best mobil bro...
#            3.0   fast safe web browser free vpn ad blocker qr c...
#            12.0  fast simpl secur googl chrome browser android ...
# 2021-01-19 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            5.0   fast safe web browser free vpn ad blocker qr c...
#            15.0  fast simpl secur googl chrome browser android ...
# 2021-01-20 1.0           puffin tv browser one app watch video web
#            2.0   small fastest secur web browser best mobil bro...
#            6.0   fast safe web browser free vpn ad blocker qr c...
#            17.0  fast simpl secur googl chrome browser android ...
# 2021-01-21 1.0   small fastest secur web browser best mobil bro...
#            3.0           puffin tv browser one app watch video web
#            4.0   fast safe web browser free vpn ad blocker qr c...
#            8.0   fast simpl secur googl chrome browser android ...
# 2021-01-22 1.0           puffin tv browser one app watch video web
#            2.0   small fastest secur web browser best mobil bro...
#            4.0   fast safe web browser free vpn ad blocker qr c...
#            17.0  fast simpl secur googl chrome browser android ...
# 2021-01-26 1.0           puffin tv browser one app watch video web
#            2.0   small fastest secur web browser best mobil bro...
#            3.0   fast safe web browser free vpn ad blocker qr c...
#            6.0   fast simpl secur googl chrome browser android ...
# 2021-01-27 1.0   fast simpl secur googl chrome browser android ...
#            2.0   small fastest secur web browser best mobil bro...
#            3.0           puffin tv browser one app watch video web
#            4.0   fast safe web browser free vpn ad blocker qr c...
# 2021-01-28 1.0   fast simpl secur googl chrome browser android ...
#            2.0   small fastest secur web browser best mobil bro...
#            3.0           puffin tv browser one app watch video web
#            4.0   fast safe web browser free vpn ad blocker qr c...
# 2021-01-29 1.0   fast simpl secur googl chrome browser android ...
#            2.0           puffin tv browser one app watch video web
#            3.0   small fastest secur web browser best mobil bro...
#            5.0   fast safe web browser free vpn ad blocker qr c...
# 2021-01-30 1.0   fast simpl secur googl chrome browser android ...
#            2.0           puffin tv browser one app watch video web
#            3.0   small fastest secur web browser best mobil bro...
#            5.0   fast safe web browser free vpn ad blocker qr c...
# 2021-01-31 1.0   fast simpl secur googl chrome browser android ...
#            2.0           puffin tv browser one app watch video web
#            3.0   small fastest secur web browser best mobil bro...
#            5.0   fast safe web browser free vpn ad blocker qr c...
# 2021-02-01 1.0   fast simpl secur googl chrome browser android ...
#            2.0   small fastest secur web browser best mobil bro...
#            3.0           puffin tv browser one app watch video web
#            7.0   fast safe web browser free vpn ad blocker qr c...
# 2021-02-03 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            3.0   fast simpl secur googl chrome browser android ...
#            4.0   fast safe web browser free vpn ad blocker qr c...
# 2021-02-04 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            3.0   fast simpl secur googl chrome browser android ...
#            4.0   fast safe web browser free vpn ad blocker qr c...
# 2021-02-05 1.0   small fastest secur web browser best mobil bro...
#            2.0           puffin tv browser one app watch video web
#            6.0   fast safe web browser free vpn ad blocker qr c...
#            20.0  fast simpl secur googl chrome browser android ...
# 2021-02-06 1.0   fast simpl secur googl chrome browser android ...
#            2.0   small fastest secur web browser best mobil bro...
#            3.0   fast safe web browser free vpn ad blocker qr c...
#            6.0           puffin tv browser one app watch video web
# 2021-02-07 1.0   fast simpl secur googl chrome browser android ...
#            3.0   fast safe web browser free vpn ad blocker qr c...
#            5.0   small fastest secur web browser best mobil bro...
#            7.0           puffin tv browser one app watch video web
# 2021-02-08 1.0   fast simpl secur googl chrome browser android ...
#            2.0   fast safe web browser free vpn ad blocker qr c...
# ...
# 2021-02-21 1.0   one smallest fastest secur web browser specif ...      11
#            2.0   puffin tv browser special edit puffin web brow...       6
#            9.0   fast safe privat introduc latest version opera...      13
#            16.0  googl chrome fast easi use secur web browser d...      14
# 2021-02-22 1.0   one smallest fastest secur web browser specif ...      11
#            2.0   puffin tv browser special edit puffin web brow...       6
#            10.0  fast safe privat introduc latest version opera...      13
#            14.0  googl chrome fast easi use secur web browser d...      14
# 2021-02-23 1.0   one smallest fastest secur web browser specif ...      11
#            2.0   puffin tv browser special edit puffin web brow...       6
#            10.0  fast safe privat introduc latest version opera...      13
#            14.0  googl chrome fast easi use secur web browser d...      14
# 2021-02-24 1.0   one smallest fastest secur web browser specif ...      11
#            2.0   puffin tv browser special edit puffin web brow...       6
#            3.0   fast safe privat introduc latest version opera...      13
#            16.0  googl chrome fast easi use secur web browser d...      14
# 2021-02-25 1.0   fast safe privat introduc latest version opera...      13
#            6.0   googl chrome fast easi use secur web browser d...      14
#            9.0   one smallest fastest secur web browser specif ...      11
#            10.0  puffin tv browser special edit puffin web brow...       6
# 2021-02-26 1.0   puffin tv browser special edit puffin web brow...       6
#            2.0   one smallest fastest secur web browser specif ...      11
#            3.0   fast safe privat introduc latest version opera...      13
#            4.0   googl chrome fast easi use secur web browser d...      14
# 2021-02-27 1.0   puffin tv browser special edit puffin web brow...       6
#            2.0   fast safe privat introduc latest version opera...      13
#            3.0   googl chrome fast easi use secur web browser d...      14
#            5.0   one smallest fastest secur web browser specif ...      11
# 2021-02-28 1.0   puffin tv browser special edit puffin web brow...       6
#            2.0   one smallest fastest secur web browser specif ...      11
#            3.0   fast safe privat introduc latest version opera...      13
#            4.0   googl chrome fast easi use secur web browser d...      14
# 2021-03-01 1.0   googl chrome fast easi use secur web browser d...      14
#            2.0   puffin tv browser special edit puffin web brow...       6
#            3.0   fast safe privat introduc latest version opera...      13
#            5.0   one smallest fastest secur web browser specif ...      11
# 2021-03-02 1.0   puffin tv browser special edit puffin web brow...       6
#            2.0   one smallest fastest secur web browser specif ...      11
#            5.0   fast safe privat introduc latest version opera...      13
#            11.0  googl chrome fast easi use secur web browser d...      14
# 2021-03-03 1.0   puffin tv browser special edit puffin web brow...       6
#            2.0   one smallest fastest secur web browser specif ...      11
#            3.0   fast safe privat introduc latest version opera...      13
#            13.0  googl chrome fast easi use secur web browser d...      14
# 2021-03-04 1.0   one smallest fastest secur web browser specif ...      11
#            5.0   puffin tv browser special edit puffin web brow...       6
#            6.0   googl chrome fast easi use secur web browser d...      14
#            9.0   fast safe privat introduc latest version opera...      13
# 2021-03-05 2.0   one smallest fastest secur web browser specif ...      11
#            5.0   puffin tv browser special edit puffin web brow...       6
#            6.0   googl chrome fast easi use secur web browser d...      14
#            8.0   fast safe privat introduc latest version opera...      13
# 2021-03-06 4.0   puffin tv browser special edit puffin web brow...       6
#            5.0   one smallest fastest secur web browser specif ...      11
#            7.0   googl chrome fast easi use secur web browser d...      14
#            10.0  fast safe privat introduc latest version opera...      13
#
#                  s_factor  l_factor
# Date       Rank
# 2020-12-16 1.0          3         3
#            2.0          5         6
#            3.0          6         8
#            4.0          4         9
# 2020-12-17 1.0          4         9
#            3.0          3         3
#            4.0          6         8
#            5.0          5         6
# 2020-12-18 2.0          3         3
#            3.0          4         9
#            5.0          5         6
#            8.0          6         8
# 2020-12-19 3.0          5         6
#            4.0          4         9
#            8.0          6         8
#            14.0         3         3
# 2020-12-21 1.0          3         3
#            2.0          5         6
#            4.0          4         9
#            6.0          6         8
# 2020-12-22 1.0          4         9
#            2.0          3         3
#            3.0          6         8
#            4.0          5         6
# 2020-12-23 1.0          5         6
#            2.0          3         3
#            3.0          4         9
#            4.0          6         8
# 2020-12-24 1.0          5         6
#            2.0          3         3
#            4.0          4         9
#            15.0         6         8
# 2020-12-25 1.0          5         6
#            2.0          3         3
#            5.0          4         9
#            11.0         6         8
# 2020-12-26 1.0          5         6
#            2.0          3         3
#            4.0          4         9
#            10.0         6         8
# 2020-12-27 1.0          5         6
#            2.0          3         3
#            3.0          6         8
#            5.0          4         9
# 2020-12-28 1.0          5         6
#            2.0          6         8
#            5.0          3         3
#            7.0          4         9
# 2020-12-29 1.0          6         8
gk.first()
# Out:
#                                                      ID  Keyword  \
# Date       Rank Date of Last Description Change
# 2020-12-16 1.0  2020-12-18                            4  browser
#                 2021-01-21                            4  browser
#                 2021-02-06                            4  browser
#                 2021-02-07                            4  browser
#            2.0  2020-12-18                            1  browser
# ...                                                 ...      ...
# 2021-03-06 4.0  2021-02-07                       131572  browser
#            5.0  2020-12-18                       131569  browser
#            7.0  2020-12-18                       131570  browser
#            10.0 2020-12-18                       131571  browser
#                 2021-02-27                       131571  browser
#
#                                                                  App ID  \
# Date       Rank Date of Last Description Change
# 2020-12-16 1.0  2020-12-18                       com cloudmosa puffinTV
#                 2021-01-21                       com cloudmosa puffinTV
#                 2021-02-06                       com cloudmosa puffinTV
#                 2021-02-07                       com cloudmosa puffinTV
#            2.0  2020-12-18                         net fast web browser
# ...                                                                 ...
# 2021-03-06 4.0  2021-02-07                       com cloudmosa puffinTV
#            5.0  2020-12-18                         net fast web browser
#            7.0  2020-12-18                           com android chrome
#            10.0 2020-12-18                            com opera browser
#                 2021-02-27                            com opera browser
#
#                                                                                  Short Description  \
# Date       Rank Date of Last Description Change
# 2020-12-16 1.0  2020-12-18                               puffin tv browser one app watch video web
#                 2021-01-21                               puffin tv browser one app watch video web
#                 2021-02-06                               puffin tv browser one app watch video web
#                 2021-02-07                               puffin tv browser one app watch video web
#            2.0  2020-12-18                       small fastest secur web browser best mobil bro...
# ...                                                                                            ...
# 2021-03-06 4.0  2021-02-07                               puffin tv browser one app watch video web
#            5.0  2020-12-18                       small fastest secur web browser best mobil bro...
#            7.0  2020-12-18                       fast simpl secur googl chrome browser android ...
#            10.0 2020-12-18                       fast safe web browser free vpn ad blocker qr c...
#                 2021-02-27                       fast safe web browser free vpn ad blocker qr c...
#
#                                                                                   Long Description  \
# Date       Rank Date of Last Description Change
# 2020-12-16 1.0  2020-12-18                       puffin tv browser special edit puffin web brow...
#                 2021-01-21                       puffin tv browser special edit puffin web brow...
#                 2021-02-06                       puffin tv browser special edit puffin web brow...
#                 2021-02-07                       puffin tv browser special edit puffin web brow...
#            2.0  2020-12-18                       one smallest fastest secur web browser specif ...
# ...                                                                                            ...
# 2021-03-06 4.0  2021-02-07                       puffin tv browser special edit puffin web brow...
#            5.0  2020-12-18                       one smallest fastest secur web browser specif ...
#            7.0  2020-12-18                       googl chrome fast easi use secur web browser d...
#            10.0 2020-12-18                       opera fast safe web browser android devic feat...
#                 2021-02-27                       fast safe privat introduc latest version opera...
#
#                                                  factor  s_factor  l_factor
# Date       Rank Date of Last Description Change
# 2020-12-16 1.0  2020-12-18                            6         3         3
#                 2021-01-21                            6         3         3
#                 2021-02-06                            6         3         3
#                 2021-02-07                            6         3         3
#            2.0  2020-12-18                           11         5         6
# ...                                                 ...       ...       ...
# 2021-03-06 4.0  2021-02-07                            6         3         3
#            5.0  2020-12-18                           11         5         6
#            7.0  2020-12-18                           14         6         8
#            10.0 2020-12-18                            9         4         5
#                 2021-02-27                           13         4         9
#
# [608 rows x 8 columns]

# %% [markdown]
# # As we can see the rank doesnt vary with date of description change
